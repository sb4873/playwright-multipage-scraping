# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!
#
# > You can use the classwork notebook and also [my Everything scraping reference](https://jonathansoma.com/everything/scraping)

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using either Playwrightfor this, *not* requests.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)

# Create a new browser window
page = await browser.new_page()

# %%
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")
# Out:
# <Response url='https://www.tdlr.texas.gov/cimsfo/fosearch.asp' request=<Request url='https://www.tdlr.texas.gov/cimsfo/fosearch.asp' method='GET'>>

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
await page.get_by_label('Search by Last Name').fill('Nguyen')

# %%
await page.locator("input[name=\"B1\"]").click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this. **I step you through things bit by bit, so it's going to be a little different than we did in class.** Also, no `pd.read_html` allowed because this isn't reaaallly tabular data (or there's just too much to clean up).
#
# Once you've loaded the page: **what selector are you going to do use to find the data?** In class we used things like `.article` or `.head-list`.
#
# > You honestly can do this all with Playwright, no BeautifulSoup involved! But we didn't cover that in class so you should stick to this method:
# >
# > ```python
# > html = await page.content()
# > doc = BeautifulSoup(html)
# > ```

# %%
html = await page.content()
doc = BeautifulSoup(html)
doc
# Out:
# <html class="supports csstransforms3d" lang="en"><head>
# <!-- Meta Tags -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <!-- Favicon -->
# <link href="/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <!-- Stylesheets -->
# <link href="/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="/css/animate.css" rel="stylesheet" type="text/css"/>
# <link href="/css/main-stylesheet.css" rel="stylesheet" type="text/css"/>
# <link href="/css/lightbox.css" rel="stylesheet" type="text/css"/>
# <link href="/css/shortcodes.css" rel="stylesheet" type="text/css"/>
# <link href="/css/custom-fonts.css" rel="stylesheet" type="text/css"/>
# <link href="/css/custom-colors.css" rel="stylesheet" type="text/css"/>
# <link href="/css/responsive.css" rel="stylesheet" type="text/css"/>
# <link href="/css/owl.carousel.css" rel="stylesheet" type="text/css"/>
# <link href="/css/owl.theme.css" rel="stylesheet" type="text/css"/>
# <link href="/css/dat-menu.css" rel="stylesheet" type="text/css"/>
# <style>
# 		* {
# 		margin: 0;
# 		}
# 		html, body {
# 		height: 100%;
# 		}
# 		form {
# 			height:100%;
# 		}
# 		.devwrapper {
# 		min-height: 100%;
# 		height: auto !important;
# 		height: 100%;
# 		margin: 0 auto -140px;
# 		}
# 		.footer, .push {
# 		height: 140px;
# 		}
#
# 		@media print {
# 			body {
# 				color: #000;
# 				background: #fff;
# 				margin-left: none;
# 				padding-left: none;
# 			}
#
# 		   .boxed.active {
# 				width: 100%;
# 				margin-left: none;
# 				padding-left: none;
# 			}
#
# 			.header {
# 				display: none;
# 			}
#
# 			.footer {
# 				display: none;
# 			}
#
# 		</style>
# <!--[if lte IE 8]>
# 		<link type="text/css" rel="stylesheet" href="/css/ie-ancient.css" />
# 		<![endif]-->
# <!-- END head -->
# <title>Administrative Orders Search Results</title>
# <!-- Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-8C39DM76B2&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MPP5WF5"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-MPP5WF5');</script>
# <!-- End Google Tag Manager -->
# <link href="css/fosearch.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="ot-menu-ipad-enable ot-menu-iphone-enable"><div class="effect-1" id="dat-menu"><div class="dat-menu-container" style='background: url("https://www.tdlr.texas.gov/images/background-1.jpg") 0% 0% / auto repeat scroll padding-box border-box rgba(0, 0, 0, 0);'><div class="dat-menu-top-header"><a class="dat-menu-menu" href="#dat-menu"><i class="fa fa-bars"></i></a><a class="dat-menu-search" href="#"><i class="fa fa-search"></i></a><a href="#"><img alt="" src="/images/logo.png" style="background-color: #0589cd;"/></a><form action=""><input name="s" type="text" value=""/><input type="submit" value=""/></form></div><div class="dat-menu-wrapper dat-menu-padding">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MPP5WF5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- TDLR_bodyheader.htm
#  NOTE: target="_blank" is used in all links so that the web application's window remains unaffected when a link is clicked
#  -->
# <!-- BEGIN .boxed -->
# <div class="boxed active">
# <div class="devwrapper">
# <!-- BEGIN .header -->
# <header class="header willfix makefixed" style="height: 111.914px;">
# <!-- BEGIN .wrapper -->
# <div class="wrapper animated bounceInDown" style="left: 50%; margin-left: -595px;">
# <div class="header-left">
# <div class="header-logo">
# <a class="otanimation" data-anim-in="flipOutX" data-anim-object=".header-logo a.otanimation img, .header-logo a.otanimation h1" data-anim-out="bounceIn" href="/index.htm"><img alt="" src="/images/logo.png"/></a>
# <strong data-anim-in="fadeOutUpBig" data-anim-out="bounceIn"><i class="fa fa-home"></i> Homepage</strong>
# </div>
# <div class="header-socials">
# <a href="http://twitter.com/TDLRLicense"><i class="fa fa-twitter"></i></a>
# <a href="http://www.facebook.com/TDLRLicense"><i class="fa fa-facebook"></i></a>
# <a href="https://www.youtube.com/user/TexasLicensing/videos"><i class="fa fa-youtube"></i></a>
# </div>
# </div>
# <div class="header-right">
# <nav class="main-menu transition-active">
# <ul class="load-responsive" rel="Main Menu">
# <li class="has-ot-mega-menu"><a href="/licenses.htm"><span>License Types <i>Regulated by TDLR</i></span></a>
# <ul class="ot-mega-menu">
# <li class="ot-dropdown menu-item">
# <ul class="widget-menu widget">
# <li><a href="/acr/acr.htm">Air Conditioning and Refrigeration Contractors</a></li>
# <li><a href="/ab/ab.htm">Elimination of Architectural Barriers</a></li>
# <li><a href="/at/at.htm">Athletic Trainers</a></li>
# <li><a href="/auc/auction.htm">Auctioneers</a></li>
# <li><a href="/barbers/barbers.htm">Barbering</a></li>
# <li><a href="/boilers/blr.htm">Boiler Safety</a></li>
# <li><a href="/sports/sports.htm">Combative Sports</a></li>
# <li><a href="/cosmet/cosmet.htm">Cosmetologists</a></li>
# <li><a href="/diet/diet.htm">Dietitians</a></li>
# <li><a href="/driver/driver.htm">Driver Education and Safety</a></li>
# <li><a href="/dtp/dtp.htm">Dyslexia Therapists and Practicioners</a></li>
# </ul>
# </li>
# <li class="ot-dropdown menu-item">
# <ul class="widget-menu widget">
# <li><a href="/electricians/elec.htm">Electricians</a></li>
# <li><a href="/elevator/ele.htm">Elevator / Escalator Safety</a></li>
# <li><a href="/legalsvcs/legalsvcs.htm">For-Profit Legal Services</a></li>
# <li><a href="/hearing/hearing.htm">Hearing Instrument Fitters and Dispensers</a></li>
# <li><a href="/ihb/ihb.htm">Industrialized Housing and Buildings</a></li>
# <li><a href="/bre/bre.htm">Licensed Breeders</a></li>
# <li><a href="/midwives/midwives.htm">Midwives</a></li>
# <li><a href="/op/op.htm">Orthotists and Prosthetists</a></li>
# <li><a href="/polygraph/polygraph.htm">Polygraph Examiners</a></li>
# <li><a href="/peo/peo.htm">Professional Employer Organizations</a></li>
</b></span></a>
# <ul class="sub-menu">
# <li><a href="/ce/cepol.htm">Polygraph Examiners</a></li>
# <li><a href="/ce/ceptc.htm">Property Tax Consultants</a></li>
# <li><a href="/ce/ceptp.htm">Property Tax Professionals</a></li>
# <li><a href="/ce/ceras.htm">Registered Accessibility Specialists</a></li>
# <li><a href="/ce/cetow.htm">Towing Operators</a></li>
# <li><a href="/ce/cewwd.htm">Well Driller and Pump Installers</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/verify.htm"><span>Search / Verify <i>Licenses or Projects</i></span></a>
# <ul>
# <li><a href="/LicenseSearch/">Search Licensees</a></li>
# <li><a href="/cimsfo/fosearch.asp">Search for Violations</a></li>
# <li><a href="/TABS/Search">Search AB Projects</a></li>
# <li><a href="/ElevatorInspection/login.aspx">Elevator Inspection Reports</a></li>
# <li><a href="/TABS/">AB Project Registration</a></li>
# <li><a href="/Boilerdata/">Search Licensed Boilers</a></li>
# <li><a href="/ihb/ihblists.htm">Search IHB Registrant Lists</a></li>
# <li><a href="/Elevator_SearchApp">Search Elevators and Related Equipment</a></li>
# <li><a href="/tools_search/">Search Tow Companies &amp; VSFs</a></li>
# </ul>
# </li>
# <div class="search-header">
# <form action="/search/search.asp" method="get">
# <input name="zoom_query" size="14" type="text"/> <input type="submit" value="Search"/>
# </form>
# </div>
# </ul></nav>
# <nav class="under-menu">
# <ul class="load-responsive" rel="Interact with TDLR">
# <li><a href="/Complaints/">File A Complaint</a></li>
# <li><a href="https://public.govdelivery.com/accounts/TXDLR/subscriber/new">E-Mail Updates From TDLR</a></li>
# <li><a href="/meetings.htm">Meetings, Commission, Rules and Statute</a></li>
# <li><a href="/employ.htm">Employment</a></li>
# <li><a href="/contact.htm">Contact TDLR</a></li>
# </ul>
# </nav>
# <!-- END .wrapper --><!-- END .header -->
# </div></div></header>
# <!-- BEGIN .content -->
# <section class="content">
# <!-- BEGIN .wrapper -->
# <div class="wrapper">
# <div class="main-content">
# <h1 style="text-align:center">Texas Department of Licensing and Regulation<br/>
# 					Administrative Orders Search Results</h1>
# <p style="text-align:center"><a href="/cimsfo/">Back to Search</a>
# </p>
# <p align="center">Data presented in Document Date (descending), Complaint#, Order Description, Respondent Name order.</p>
# <p>  99 records found.</p><table style="border: 1px solid #c2c2c2; padding:4px; margin-left:auto; margin-right:auto; WIDTH: 100%"><tbody><tr><th style="padding:4px; text-align:left; background:#c2c2c2;">Name and Location</th><th style="padding:4px; text-align:left; background:#c2c2c2;">Order</th><th style="padding:4px; text-align:left; background:#c2c2c2;">Basis for Order</th></tr><tr style="background:#ffffff;"> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:22%;"><span class="results_text">NGUYEN, THU THI </span><br/> <span class="default_text">City:</span> <span class="results_text">HOUSTON</span><br/> <span class="default_text">County:</span> <span class="results_text">HARRIS</span><br/> <span class="default_text">Zip Code:</span> <span class="results_text">77031</span><br/><br/><br/><span class="default_text"> License #:</span> <span class="results_text">816854</span><br/><br/><span class="default_text">Complaint #</span> <span class="results_text">COS20230009980</span></td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;"><span class="default_text">Date:</span> <span class="results_text">10/23/2023</span><br/><br/>Respondents Thu Thi Nguyen and Tien Minh Vo are assessed an administrative penalty in the amount of $1,350.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to discard single use implements after each use; Respondents failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.</td></tr><tr style="background:#dedede;"> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:22%;"><span class="results_text">NGUYEN, TUONG </span><br/> <span class="default_text">City:</span> <span class="results_text">FORT WORTH</span><br/> <span class="default_text">County:</span> <span class="results_text">TARRANT</span><br/> <span class="default_text">Zip Code:</span> <span class="results_text">76120</span><br/><br/><br/><span class="default_text"> License #:</span> <span class="results_text">742271</span><br/><br/><span class="default_text">Complaint #</span> <span class="results_text">COS20230001960</span></td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;"><span class="default_text">Date:</span> <span class="results_text">10/4/2023</span><br/><br/>Respondents Trang Phan, Tuong Nguyen, and Victory Lotus LLC are assessed an administrative penalty in the amount of $2,575.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondents employed an individual as an operator who had not obtained a cosmetology license; Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondents failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondents failed to keep all pr ...
#
# Respondent's Speech Language Pathologist Assistant license is revoked.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondent falsified records, the Department is charging 5 violations.</td></tr><tr style="background:#dedede;"> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:22%;"><span class="results_text">NGUYEN, MUOI </span><br/> <span class="default_text">City:</span> <span class="results_text">SAN ANTONIO</span><br/> <span class="default_text">County:</span> <span class="results_text">BEXAR</span><br/> <span class="default_text">Zip Code:</span> <span class="results_text">78233</span><br/><br/><br/><span class="default_text"> License #(s):</span> <span class="results_text">737181, 1141645</span><br/><br/><span class="default_text">Complaint #</span> <span class="results_text">COS20210013960</span></td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;"><span class="default_text">Date:</span> <span class="results_text">11/16/2022</span><br/><br/>Respondent is assessed an administrative penalty in the amount of $1,325.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.</td></tr><tr style="background:#ffffff;"> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:22%;"><span class="results_text">NGUYEN, CHARLIE </span><br/> <span class="default_text">City:</span> <span class="results_text">DALLAS</span><br/> <span class="default_text">County:</span> <span class="results_text">DALLAS</span><br/> <span class="default_text">Zip Code:</span> <span class="results_text">75219</span><br/><br/><br/><span class="default_text"> License #:</span> <span class="results_text">763659</span><br/><br/><span class="default_text">Complaint #</span> <span class="results_text">COS20210015021</span></td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;"><span class="default_text">Date:</span> <span class="results_text">11/4/2022</span><br/><br/>Respondent is assessed an administrative penalty in the amount of $1,125.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.</td></tr><tr style="background:#dedede;"> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:22%;"><span class="results_text">NGUYEN, TONY VAN </span><br/> <span class="default_text">City:</span> <span class="results_text">SAN ANTONIO</span><br/> <span class="default_text">County:</span> <span class="results_text">BEXAR</span><br/> <span class="default_text">Zip Code:</span> <span class="results_text">78230</span><br/><br/><br/><span class="default_text"> License #:</span> <span class="results_text">747322</span><br/><br/><span class="default_text">Complaint #</span> <span class="results_text">COS20210015551</span></td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;"><span class="default_text">Date:</span> <span class="results_text">11/4/2022</span><br/><br/>Respondent is assessed an administrative penalty in the amount of $500.</td> <td style="padding:4px; text-align:left; font-size:11px; font:Arial, Helvetica, sans-serif; width:39%;">Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.</td></tr><tr style="background:#ffffff;"> <td style="pa ...
# <p style="text-align:center"><a href="#top">Top</a> | <a href="/cimsfo/">Back to Search</a></p>
# </div>
# <!-- END .wrapper -->
# </div>
# <!-- END .content -->
# </section>
# <div class="push">
# </div>
# <!-- for sticky footer -->
# </div>
# <!-- END .devwrapper -->
# <!-- BEGIN .footer -->
# <footer class="footer">
# <!-- BEGIN .wrapper -->
# <div class="wrapper">
# <div class="footer-widgets">
# <!-- BEGIN .widget -->
# <div class="widget">
# <div>
# <ul>
# <li><a href="/disclaimer.htm">Privacy and Security Policy</a></li>
# <li><a href="/disclaimer.htm#access">Accessibility</a></li>
# <li><a href="/disclaimer.htm#PublicInfoPolicy">Open Records Policy</a></li>
# <li><a href="/disclaimer.htm#link">Link Policy</a></li>
# </ul>
# </div>
# <!-- END .widget -->
# </div>
# <!-- BEGIN .widget -->
# <div class="widget">
# <div>
# <ul>
# <li><a href="/compact.htm">Compact with Texans</a></li>
# <li><a href="https://www.texas.gov/">Texas.gov</a></li>
# <li><a href="https://www.tsl.texas.gov/trail/index.html">Statewide Search</a></li>
# </ul>
# </div>
# <!-- END .widget -->
# </div>
# <!-- BEGIN .widget -->
# <div class="widget">
# <div>
# <ul>
# <li><a href="http://governor.state.tx.us/homeland">Texas Homeland Security</a></li>
# <li><a href="http://www.texastransparency.org/">Texas Transparency</a></li>
# <li><a href="http://veterans.portal.texas.gov/en/Pages/default.aspx">Texas Veterans
#                             Portal</a></li>
# </ul>
# </div>
# <!-- END .widget -->
# </div>
# </div>
# <!-- END .wrapper -->
# </div>
# <!-- END .footer -->
# </footer>
# <!-- END .boxed -->
# </div>
# <!-- Scripts -->
# <script src="/jscript/jquery-latest.min.js" type="text/javascript"></script>
# <script src="/jscript/snap.svg-min.js" type="text/javascript"></script>
# <script src="/jscript/theme-scripts.js" type="text/javascript"></script>
# <script src="/jscript/lightbox.js" type="text/javascript"></script>
# <script src="/jscript/owl.carousel.min.js" type="text/javascript"></script>
# <script src="/jscript/SmoothScroll.min.js" type="text/javascript"></script>
# <script src="/jscript/iscroll.js" type="text/javascript"></script>
# <script src="/jscript/modernizr.custom.50878.js" type="text/javascript"></script>
# <script src="/jscript/dat-menu.js" type="text/javascript"></script>
# <script>
#     jquery(document).ready(function () {
#         jquery(".ot-slider").owlCarousel({
#             items: 1,
#             autoPlay: true,
#             stopOnHover: true,
#             navigation: true,
#             lazyLoad: true,
#             singleItem: true,
#             pagination: false
#         });
#
#         jquery(".gallery-shortcode-photos").owlCarousel({
#             items: 3,
#             autoPlay: false,
#             stopOnHover: true,
#             navigation: false,
#             lazyLoad: true,
#             singleItem: false,
#             pagination: true
#         });
#
#         jquery(".similar-articles-list .similar-articles").owlCarousel({
#             items: 4,
#             autoPlay: false,
#             stopOnHover: true,
#             navigation: false,
#             lazyLoad: true,
#             singleItem: false,
#             pagination: true
#         });
#     });
# </script>
# <div style="clear: both;"></div></div></div><nav class="dat-menu-list dat-submenu" style="touch-action: none;"><ul id="dat-menu-list-inner" style="transform: translate(0px, 0px) translateZ(0px);"><li class="dat-menu-header"><span>Main Menu</span></li>
# <li class="has-ot-mega-menu dat-has-sub"><a href="/licenses.htm"><span>License Types <i>Regulated by TDLR</i></span></a>
# <ul class="ot-mega-menu">
# <li class="ot-dropdown menu-item dat-has-sub">
# <ul class="widget-menu widget">
# <li><a href="/acr/acr.htm">Air Conditioning and Refrigeration Contractors</a></li>
# <li><a href="/ab/ab.htm">Elimination of Architectural Barriers</a></li>
# <li><a href="/at/at.htm">Athletic Trainers</a></li>
# <li><a href="/meetings.htm">Meetings, Commission, Rules and Statute</a></li>
# <li><a href="/employ.htm">Employment</a></li>
# <li><a href="/contact.htm">Contact TDLR</a></li>
# </ul></nav></div></body></html>

# %% [markdown]
# ### Grab the rows, loop through each result and print the entire row
#
# It's probably too many rows to do all at once: once you have a list, use `[:10]` to only show the first ten! For example, if you saved the table rows into `results` you might do something like this:
#
# ```python
# for result in results[:10]:
#     print("------")
#     print(result)
# ```
#
# Although you'd want to print out the text from the row (I give example output below).

# %%
rows = doc.select('tr')

for row in rows[:10]:
    lines = row.get_text(separator='\n')
    print("------")
    print(lines)
# Out:
# ------
# Name and Location
# Order
# Basis for Order
# ------
#
# NGUYEN, THU THI
#
# City:
#
# HOUSTON
#
# County:
#
# HARRIS
#
# Zip Code:
#
# 77031
#  License #:
#
# 816854
# Complaint #
#
# COS20230009980
#
# Date:
#
# 10/23/2023
# Respondents Thu Thi Nguyen and Tien Minh Vo are assessed an administrative penalty in the amount of $1,350.
#
# Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to discard single use implements after each use; Respondents failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# ------
#
# NGUYEN, TUONG
#
# City:
#
# FORT WORTH
#
# County:
#
# TARRANT
#
# Zip Code:
#
# 76120
#  License #:
#
# 742271
# Complaint #
#
# COS20230001960
#
# Date:
#
# 10/4/2023
# Respondents Trang Phan, Tuong Nguyen, and Victory Lotus LLC are assessed an administrative penalty in the amount of $2,575.
#
# Respondents employed an individual as an operator who had not obtained a cosmetology license; Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondents failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondents failed to keep all products properly labeled in compliance with OSHA requirements.
# ------
#
# NGUYEN, HUONG T
#
# City:
#
# SAN ANTONIO
#
# County:
#
# BEXAR
#
# Zip Code:
#
# 78259
#  License #:
#
# 775126
# Complaint #
#
# COS20220017901
#
# Date:
#
# 8/23/2023
# Respondent is assessed an administrative penalty in the amount of $1,250.
#
# Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ------
#
# NGUYEN, STEVEN QUOC
#
# City:
#
# SAN ANGELO
#
# County:
#
# TOM GREEN
#
# Zip Code:
#
# 76904
#  License #(s):
#
# 748707, 1458935
# Complaint #
#
# COS20220018135
#
# Date:
#
# 7/28/2023
# Respondent is assessed an administrative penalty in the amount of $2,000.
#
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent employed an individual as an operator who had not obtained a cosmetology license, the Department is charging 3 violations.
# ------
#
# NGUYEN, HUONG THI NGOC
#
# City:
#
# MANSFIELD
#
# County:
#
# TARRANT
#
# Zip Code:
#
# 76063
#  License #:
#
# 829081
# Complaint #
#
# COS20220016107
#
# Date:
#
# 7/24/2023
# Respondent is assessed an administrative penalty in the amount of $1,150.
#
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations.
# ------
#
# NGUYEN, TAMMY
#
# City:
#
# TOMBALL
#
# County:
#
# HARRIS
#
# Zip Code:
#
# 77375
# NGUYEN, THANG
#
# City:
#
# TOMBALL
#
# County:
#
# HARRIS
#
# Zip Code:
#
# 77375
#  License #:
#
# 789659
# Complaint #
#
# COS20220013443
#
# Date:
#
# 7/17/2023
# Respondents are assessed an administrative penalty in the amount of $500.
#
# Respondents employed an unlicensed individual to perform cosmetology services.
# ------
#
# NGUYEN, TOAN DUC
#
# City:
#
# SUGAR LAND
#
# County:
#
# FORT BEND
#
# Zip Code:
#
# 77478
#  License #:
#
# 789406
# Complaint #
#
# COS20220015714
#
# Date:
#
# 7/17/2023
# Respondent is assessed an administrative penalty in the amount of $2,125.
#
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ------
#
# NGUYEN, NHAN TRONG
#
# City:
#
# SAN ANTONIO
#
# County:
#
# BEXAR
#
# Zip Code:
#
# 78247
#  License #(s):
#
# 694927, 1096417
# Complaint #
#
# COS20220012646
#
# Date:
#
# 7/13/2023
# Respondent is assessed an administrative penalty in the amount of $2,500.
#
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required;  Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ------
#
# NGUYEN, TAM PHUONG
#
# City:
#
# SAN ANTONIO
#
# County:
#
# BEXAR
#
# Zip Code:
#
# 78259
#  License #(s):
#
# 731908, 828834
# Complaint #
#
# COS20220012645
#
# Date:
#
# 7/5/2023
# Respondent is assessed an administrative penalty in the amount of $1,875.
#
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.

# %% [markdown]
# The result should look something like this:
#
# ```
# Name and Location Order Basis for Order
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20210004784 Date: 11/16/2021
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, LONG D
# City: SAN SABA
# County: SAN SABA
# Zip Code: 76877
# ```

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll probably get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything when there's an error, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**
#
# Output should look like this:
#
# ```
# Doesn't have a name
# NGUYEN, THANH
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, JIMMY
# ```
#
# * *Tip: The name has a class you can use. The class name is reused in a lot of places, but because it's the first one you don't have to worry about that!*
# * *Tip: Instead of searching across the entire page – like `doc.select_one` – you should be doing your searching just inside of each **row** (I used this technique in the beginning of class with BeautifulSoup when we were scraping the books page)*

# %%
for row in rows[:10]:
    try :
        print(row.select_one('.results_text').text)
    except:
       print("It didn't work")
# Out:
# It didn't work
# NGUYEN, THU THI
# NGUYEN, TUONG
# NGUYEN, HUONG T
# NGUYEN, STEVEN QUOC
# NGUYEN, HUONG THI NGOC
# NGUYEN, TAMMY
# NGUYEN, TOAN DUC
# NGUYEN, NHAN TRONG
# NGUYEN, TAM PHUONG

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# Your results should look something like:
#
# ```
# Doesn't have a violation
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ...
# ```
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: Or I guess you could just skip the one with the problem using try/except...*

# %%
for row in rows[:10] :
    try :
        violation = row.select('td')[2]
        print("---")
        print(violation.text)
    except :
        print("It didnt work")
# Out:
# It didnt work
# ---
# Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to discard single use implements after each use; Respondents failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# ---
# Respondents employed an individual as an operator who had not obtained a cosmetology license; Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondents failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondents failed to keep all products properly labeled in compliance with OSHA requirements.
# ---
# Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ---
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent employed an individual as an operator who had not obtained a cosmetology license, the Department is charging 3 violations.
# ---
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations.
# ---
# Respondents employed an unlicensed individual to perform cosmetology services.
# ---
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ---
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required;  Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ---
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# Output should look similar to this:
#
# ```
# Doesn't have a complaint number
# COS20210004784
# COS20210009745
# COS20210011484
# ...
# ```
#
# - *Tip: Think about the order of the elements. Can you count from the opposite direction than you normally do?*

# %%
for row in rows[:10] :
    try :
        numbers = row.td.find_all('span')
        print("---")
        print(numbers[-1].text)
    except :
        print("It didnt work")
# Out:
# It didnt work
# ---
# COS20230009980
# ---
# COS20230001960
# ---
# COS20220017901
# ---
# COS20220018135
# ---
# COS20220016107
# ---
# COS20220013443
# ---
# COS20220015714
# ---
# COS20220012646
# ---
# COS20220012645

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# Based on what you print out, the output might look something like:
#
# ```
# This row is broken: Name and Location Order Basis for Order
# {'name': 'NGUYEN, THANH', 'city': 'FRISCO', 'county': 'COLLIN', 'zip_code': '75034', 'complaint_no': 'COS20210004784', 'license_numbers': '790672', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, LONG D', 'city': 'SAN SABA', 'county': 'SAN SABA', 'zip_code': '76877', 'complaint_no': 'COS20210009745', 'license_numbers': '760420, 1620583', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# ```
#
# > _**Tip:** Depending on how you do this, you might want to figure out how to search for "next siblings" or "following siblings"_

# %%
list_of_dicts = []

for row in rows[1:10] :
    name = row.select_one('.results_text').text
    city = row.select('.results_text')[1].text
    county = row.select('.results_text')[2].text
    zip_code = row.select('.results_text')[3].text
    complaint_no = row.td.find_all('span')[-1].text
    license_numbers = row.select('.results_text')[4].text
    complaint = row.select('td')[2].text

    dict_nguyens = {
        'name' : name,
        'city' : city,
        'county' : county,
        'zip_code' : zip_code,
        'complaint_no' : complaint_no,
        'license_numbers' : license_numbers,
        'complaint' : complaint  
    }
    list_of_dicts.append(dict_nguyens)
list_of_dicts
# Out:
# [{'name': 'NGUYEN, THU THI ',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip_code': '77031',
#   'complaint_no': 'COS20230009980',
#   'license_numbers': '816854',
#   'complaint': "Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to discard single use implements after each use; Respondents failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."},
#  {'name': 'NGUYEN, TUONG ',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip_code': '76120',
#   'complaint_no': 'COS20230001960',
#   'license_numbers': '742271',
#   'complaint': "Respondents employed an individual as an operator who had not obtained a cosmetology license; Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondents failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondents failed to keep all products properly labeled in compliance with OSHA requirements."},
#  {'name': 'NGUYEN, HUONG T',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78259',
#   'complaint_no': 'COS20220017901',
#   'license_numbers': '775126',
#   'complaint': 'Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'},
#  {'name': 'NGUYEN, STEVEN QUOC ',
#   'city': 'SAN ANGELO',
#   'county': 'TOM GREEN',
#   'zip_code': '76904',
#   'complaint_no': 'COS20220018135',
#   'license_numbers': '748707, 1458935',
#   'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent employed an individual as an operator who had not obtained a cosmetology license, the Department is charging 3 violations.'},
#  {'name': 'NGUYEN, HUONG THI NGOC ',
#   'city': 'MANSFIELD',
#   'county': 'TARRANT',
#   'zip_code': '76063',
#   'complaint_no': 'COS20220016107',
#   'license_numbers': '829081',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations.'},
#  {'name': 'NGUYEN, TAMMY ',
#   'city': 'TOMBALL',
#   'county': 'HARRIS',
#   'zip_code': '77375',
#   'complaint_no': 'COS20220013443',
#   'license_numbers': 'NGUYEN, THANG ',
#   'complaint': 'Respondents employed an unlicensed individual to perform cosmetology services.'},
#  {'name': 'NGUYEN, TOAN DUC ',
#   'city': 'SUGAR LAND',
#   'county': 'FORT BEND',
#   'zip_code': '77478',
#   'complaint_no': 'COS20220015714',
#   'license_numbers': '789406',
#   'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, NHAN TRONG ',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78247',
#   'complaint_no': 'COS20220012646',
#   'license_numbers': '694927, 1096417',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required;  Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'},
#  {'name': 'NGUYEN, TAM PHUONG ',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip_code': '78259',
#   'complaint_no': 'COS20220012645',
#   'license_numbers': '731908, 828834',
#   'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}]

# %% [markdown]
# ### Save that to a CSV named `output.csv`
#
# The dataframe should look something like...
#
# |index|name|city|county|zip_code|complaint_no|license_numbers|complaint|
# |---|---|---|---|---|---|---|---|
# |0|NGUYEN, THANH|FRISCO|COLLIN|75034|COS20210004784|790672|Respondent failed to clean and sanitize whirlp...|
# |1|NGUYEN, LONG D|SAN SABA|SAN SABA|76877|COS20210009745|760420, 1620583|Respondent failed to keep a record of the date...|
#
#
# - *Tip: If you send a list of dictionaries to `pd.DataFrame(...)`, it will create a dataframe out of that list!*

# %%
df = pd.DataFrame(list_of_dicts)
df
# Out:
#                       name         city     county zip_code    complaint_no  \
# 0         NGUYEN, THU THI       HOUSTON     HARRIS    77031  COS20230009980
# 1           NGUYEN, TUONG    FORT WORTH    TARRANT    76120  COS20230001960
# 2          NGUYEN, HUONG T  SAN ANTONIO      BEXAR    78259  COS20220017901
# 3     NGUYEN, STEVEN QUOC    SAN ANGELO  TOM GREEN    76904  COS20220018135
# 4  NGUYEN, HUONG THI NGOC     MANSFIELD    TARRANT    76063  COS20220016107
# 5           NGUYEN, TAMMY       TOMBALL     HARRIS    77375  COS20220013443
# 6        NGUYEN, TOAN DUC    SUGAR LAND  FORT BEND    77478  COS20220015714
# 7      NGUYEN, NHAN TRONG   SAN ANTONIO      BEXAR    78247  COS20220012646
# 8      NGUYEN, TAM PHUONG   SAN ANTONIO      BEXAR    78259  COS20220012645
#
#    license_numbers                                          complaint
# 0           816854  Respondents failed to clean, disinfect, and st...
# 1           742271  Respondents employed an individual as an opera...
# 2           775126  Respondent failed to clean and disinfect facia...
# 3  748707, 1458935  Respondent failed to cooperate with the inspec...
# 4           829081  Respondent failed to clean, disinfect, and ste...
# 5   NGUYEN, THANG   Respondents employed an unlicensed individual ...
# 6           789406  Respondent failed to clean, disinfect, and ste...
# 7  694927, 1096417  Respondent failed to follow whirlpool foot spa...
# 8   731908, 828834  Respondent failed to follow whirlpool foot spa...

# %%
df.to_csv('output2.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('output2.csv')
# Out:
#                       name         city     county  zip_code    complaint_no  \
# 0         NGUYEN, THU THI       HOUSTON     HARRIS     77031  COS20230009980
# 1           NGUYEN, TUONG    FORT WORTH    TARRANT     76120  COS20230001960
# 2          NGUYEN, HUONG T  SAN ANTONIO      BEXAR     78259  COS20220017901
# 3     NGUYEN, STEVEN QUOC    SAN ANGELO  TOM GREEN     76904  COS20220018135
# 4  NGUYEN, HUONG THI NGOC     MANSFIELD    TARRANT     76063  COS20220016107
# 5           NGUYEN, TAMMY       TOMBALL     HARRIS     77375  COS20220013443
# 6        NGUYEN, TOAN DUC    SUGAR LAND  FORT BEND     77478  COS20220015714
# 7      NGUYEN, NHAN TRONG   SAN ANTONIO      BEXAR     78247  COS20220012646
# 8      NGUYEN, TAM PHUONG   SAN ANTONIO      BEXAR     78259  COS20220012645
#
#    license_numbers                                          complaint
# 0           816854  Respondents failed to clean, disinfect, and st...
# 1           742271  Respondents employed an individual as an opera...
# 2           775126  Respondent failed to clean and disinfect facia...
# 3  748707, 1458935  Respondent failed to cooperate with the inspec...
# 4           829081  Respondent failed to clean, disinfect, and ste...
# 5   NGUYEN, THANG   Respondents employed an unlicensed individual ...
# 6           789406  Respondent failed to clean, disinfect, and ste...
# 7  694927, 1096417  Respondent failed to follow whirlpool foot spa...
# 8   731908, 828834  Respondent failed to follow whirlpool foot spa...
